# %%
import pandas as pd
import numpy as np
import os
import sys 
sys.path.append(os.path.abspath(os.path.join('..'))) # Access the src folder
from src.data_processing import FeatureAggregator, TimeFeatureExtractor, get_preprocessing_pipeline

# %%
# 1. Load Cleaned Data
df = pd.read_csv('../data/processed/cleaned_data.csv', parse_dates=['TransactionStartTime'])

# 2. Run Custom Extractions
aggregator = FeatureAggregator()
time_extractor = TimeFeatureExtractor()

df = aggregator.transform(df)
df = time_extractor.transform(df)

# 3. Define columns for the Pipeline
num_features = ['Amount', 'Value', 'Total_Amount', 'Average_Amount', 'Transaction_Count', 'Std_Dev_Amount']
cat_features = ['ProductCategory', 'ChannelId', 'PricingStrategy']

# 4. Apply Pipeline
pipeline = get_preprocessing_pipeline(num_features, cat_features)
X_processed = pipeline.fit_transform(df)

# Save for Task 4
df.to_csv('../data/processed/featured_data.csv', index=False)
